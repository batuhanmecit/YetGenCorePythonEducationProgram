# %%
#PARAMETRELER
print("Hello" , " World", sep="")
print("Hello" , " World" , sep=",") 
print("Ankara" , " İzmir" , "İstanbul" , sep="/") #Burada sep parametresini öğrendik: Virgül olan yerlere hangi işaretin geleceğini yazdık bir üst örnekte virgül koymuştur burada / koyduk
print("YetGen eğitimi başladı" , end="!") #Burada end parametresini öğrendik

#VARIABLES (tek bir değişkeni değiştirerek bütün kodlara ekleme veya çıkarma işlemi yapabiliriz)
yetgen = "YetGen Jump"
print(yetgen)
print(yetgen)
print(yetgen)

IsimSoyisim = "isim soyisim"  #İlk harfler büyük diğerleri küçük bunlara Camel Case denir.
isim_soyisim = "isim soyisim" #Kelimenin bittiği yere '_' koymaya Snake Case denir.

#Type() Komutu (Veri Tipini verir:Integer, Float, String, Boolean)
print(type("Batuhan"))
print(type(5))
print(type(5.14))
print(type(True))
type(5)
# Out:
# Hello World
# Hello, World
# Ankara/ İzmir/İstanbul
# YetGen eğitimi başladı!YetGen Jump
# YetGen Jump
# YetGen Jump
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# int
